# %%
# !git clone https://github.com/mehtab78/DL_projects.git
# %cd DL_projects
# Out:
# Cloning into 'DL_projects'...
# remote: Enumerating objects: 20088, done.
# remote: Total 20088 (delta 0), reused 0 (delta 0), pack-reused 20088 (from 1)
# Receiving objects: 100% (20088/20088), 156.79 MiB | 15.55 MiB/s, done.
# Resolving deltas: 100% (30/30), done.
# Updating files: 100% (20058/20058), done.
# /content/DL_projects

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.6/57.6 kB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.3/78.3 kB 3.8 MB/s eta 0:00:00
# ...
#   Attempting uninstall: tqdm
#     Found existing installation: tqdm 4.67.1
#     Uninstalling tqdm-4.67.1:
#       Successfully uninstalled tqdm-4.67.1
#   Attempting uninstall: termcolor
#     Found existing installation: termcolor 3.0.1
#     Uninstalling termcolor-3.0.1:
#       Successfully uninstalled termcolor-3.0.1
# ...

# %%
# !rm -rf drive_data
# !curl -s -L https://www.cs.utexas.edu/~bzhou/dl_class/drive_data.zip -o ./drive_data.zip && unzip -qo drive_data.zip
# %ls
# Out:
# assets/    drive_data/     grader/    README.md
# bundle.py  drive_data.zip  homework/  requirements.txt

# %%
# %load_ext autoreload
# %autoreload 2
# %pwd
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# '/content/DL_projects'

# %%
for model in ["mlp_planner", "transformer_planner", "cnn_planner"]:
    print(f"Training with model: {model}")
    # !python3 -m homework.train_planner --model {model} --batch_size 128 --epochs 40 --dataset drive_data/train
# Out:
# Training with model: mlp_planner
# Loaded 8000 samples from 16 episodes
# Starting training for 40 epochs...
# Epoch 1/40: Loss = 2.2384
# Epoch 2/40: Loss = 1.7708
# Epoch 3/40: Loss = 1.7518
# Epoch 4/40: Loss = 1.7356
# Epoch 5/40: Loss = 1.7332
# Epoch 6/40: Loss = 1.7263
# Epoch 7/40: Loss = 1.7231
# Epoch 8/40: Loss = 1.7106
# Epoch 9/40: Loss = 1.7223
# Epoch 10/40: Loss = 1.7027
# Epoch 11/40: Loss = 1.7129
# Epoch 12/40: Loss = 1.7015
# Epoch 13/40: Loss = 1.7061
# Epoch 14/40: Loss = 1.7001
# Epoch 15/40: Loss = 1.6902
# Epoch 16/40: Loss = 1.7005
# Epoch 17/40: Loss = 1.6933
# Epoch 18/40: Loss = 1.6903
# Epoch 19/40: Loss = 1.6937
# Epoch 20/40: Loss = 1.6875
# Epoch 21/40: Loss = 1.6856
# Epoch 22/40: Loss = 1.6847
# Epoch 23/40: Loss = 1.6863
# Epoch 24/40: Loss = 1.6821
# Epoch 25/40: Loss = 1.6823
# Epoch 26/40: Loss = 1.6877
# Epoch 27/40: Loss = 1.6924
# Epoch 28/40: Loss = 1.6780
# Epoch 29/40: Loss = 1.6754
# Epoch 30/40: Loss = 1.6774
# ...

# %%
# !sudo DEBIAN_FRONTEND=noninteractive apt install -qq libnvidia-gl-535
# !pip install PySuperTuxKartData --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk
# !pip install PySuperTuxKart --index-url=https://www.cs.utexas.edu/~bzhou/dl_class/pystk
# Out:
# The following additional packages will be installed:
#   libnvidia-common-535
# The following NEW packages will be installed:
#   libnvidia-common-535 libnvidia-gl-535
# 0 upgraded, 2 newly installed, 0 to remove and 30 not upgraded.
# Need to get 183 MB of archives.
# After this operation, 464 MB of additional disk space will be used.
# Selecting previously unselected package libnvidia-common-535.
# (Reading database ... 126315 files and directories currently installed.)
# Preparing to unpack .../libnvidia-common-535_535.230.02-0ubuntu1_all.deb ...
# Unpacking libnvidia-common-535 (535.230.02-0ubuntu1) ...
# Selecting previously unselected package libnvidia-gl-535:amd64.
# Preparing to unpack .../libnvidia-gl-535_535.230.02-0ubuntu1_amd64.deb ...
# dpkg-query: no packages found matching libnvidia-gl-450
# Unpacking libnvidia-gl-535:amd64 (535.230.02-0ubuntu1) ...
# Setting up libnvidia-common-535 (535.230.02-0ubuntu1) ...
# ...

# %%
# !python3 -m grader homework -vv --disable_color
# Out:
# Public grader loaded.
# [DEBUG    00:00:000] Loading assignment
# [DEBUG    00:00:000] Loading grader
# [INFO     00:00:002] MLP Planner
# [DEBUG    00:00:057] Loaded 2000 samples from 4 episodes
# [INFO     00:00:320]   - Test Output Shape                                  [ 5 / 5 ]
# [INFO     00:01:199]   - Longitudinal Error                                 [ 10 / 10 ]
# [WARNING  00:01:199] longitudinal_error: 0.137, required < 0.2
# [INFO     00:01:199]   - Longitudinal Error: Extra Credit                   [ 1 / 1 ]
# [INFO     00:01:199]   - Lateral Error                                      [ 10 / 10 ]
# [WARNING  00:01:199] lateral_error: 0.467, required < 0.6
# [INFO     00:01:199]   - Lateral Error: Extra Credit                        [ 1 / 1 ]
# [INFO     00:16:213]   - Driving Performance                                [ 10 / 10 ]
# [WARNING  00:16:213] track coverage: 0.895, required > 0.5
# ...

# %%
# !python3 -m homework.supertux_utils.evaluate --model mlp_planner --track lighthouse --max-steps 100
# Out:
# 100% 100/100 [00:08<00:00, 12.08it/s]
# 100 frames saved to videos/mlp_planner_lighthouse.mp4 @ 20fps

# %%
# !python3 -m homework.supertux_utils.evaluate --model transformer_planner --track lighthouse --max-steps 100
# Out:
# 100% 100/100 [00:08<00:00, 11.13it/s]
# 100 frames saved to videos/transformer_planner_lighthouse.mp4 @ 20fps

# %%
# !python3 -m homework.supertux_utils.evaluate --model cnn_planner --track lighthouse --max-steps 100
# Out:
# 100% 100/100 [00:08<00:00, 11.63it/s]
# 100 frames saved to videos/cnn_planner_lighthouse.mp4 @ 20fps

# %%
from IPython.display import Video
from pathlib import Path

video_dir = Path("videos")
video_files = list(sorted(video_dir.glob("*.mp4")))


first_video = video_files[0]
print(f"Video Path: {first_video}")
display(Video(str(first_video), embed=True))
# Out:
# Video Path: videos/cnn_planner_lighthouse.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
first_video = video_files[1]
print(f"Video Path: {first_video}")
display(Video(str(first_video), embed=True))
# Out:
# Video Path: videos/mlp_planner_lighthouse.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>

# %%
first_video = video_files[2]
print(f"Video Path: {first_video}")
display(Video(str(first_video), embed=True))
# Out:
# Video Path: videos/transformer_planner_lighthouse.mp4
# <video controls  >
#  <source src="data:video/mp4;base64,..." type="video/mp4">
#  Your browser does not support the video tag.
#  </video>
